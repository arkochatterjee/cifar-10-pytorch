# %% [markdown]
# ## ECS659P/7026P Neural Networks and Deep Learning : Coursework Report - CIFAR-10 Classification
#
# Arko Chatterjee
#
# MSc Big Data Science
#
# (Student ID : 210804539)

# %%
'''
importing required dependencies
'''

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torch.optim.lr_scheduler as lr_scheduler
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
'''
checking gpu resource!
'''

num_gpus = torch.cuda.device_count()
for i in range(num_gpus):
    device_props = torch.cuda.get_device_properties(i)
    print(f"GPU {i}: {device_props.name}, {device_props.multi_processor_count} cores")
# Out:
# GPU 0: NVIDIA A100 80GB PCIe, 108 cores

# %%
'''
assigning device = cuda if gpu is available else cpu
'''

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
# define batch size for train + test dataloader
batch_size = 32


# initialize dataloader 

transform_train = transforms.Compose([
    transforms.Resize(32), # resize image to 32x32
    transforms.RandomCrop(32, padding=2), #  randomly crop input image -> 32x32 with padding = 2
    transforms.RandomHorizontalFlip(), # data augmentation by horizontal flip of data
    transforms.ToTensor(), # convert to pytorch tensor
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]) # normalize tensor value
])

transform_test = transforms.Compose([
    transforms.Resize(32),# resize image to 32x32
    transforms.ToTensor(), # convert to pytorch tensor
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]) # normalize tensor value
])

'''
please note : download is set = True, so dataset will download to root directory!
'''
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_train)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=True, num_workers=2)

# define labels
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# visualize dataset

def imshow(img):
    transform = transforms.Compose([transforms.Resize((128, 128))])
    img = transform(img)
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    fig, ax = plt.subplots(figsize=(2, 2))
    ax.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

count = 5
dataiter = iter(trainloader)
images, labels = next(dataiter)
images, labels = images[:count], labels[:count] # first n training images from count variable

for single in range(0,count):
    print('Training Data : ' , (single+1))
    label_class = classes[labels[single]]
    print('Class Label : ', label_class)
    imshow(images[single])
    print('--------------------------------')
# Out:
# Training Data :  1
# Class Label :  ship
# --------------------------------
# Training Data :  2
# Class Label :  truck
# --------------------------------
# Training Data :  3
# Class Label :  dog
# --------------------------------
# Training Data :  4
# Class Label :  car
# --------------------------------
# Training Data :  5
# Class Label :  car
# --------------------------------

# %%
'''
understanding our dataset
'''

print('total train dataset :', len(trainset))
print('total test dataset :', len(testset))
print('batch size :' , batch_size)
print('train loader size :', len(trainloader))
print('test loader size :', len(testloader))
# Out:
# total train dataset : 50000
# total test dataset : 10000
# batch size : 32
# train loader size : 1563
# test loader size : 313

# %%
'''
defining class Block - architected as per defined in the coursework!

each block should provide the output for K iterations : 

->  out = a_1 * conv_1(x) + ..... + a_K * conv_K(x)
->  a = non-linear activation * spatial avg pool (x)
->  x = input image tensor
'''

class Block(nn.Module):
    def __init__(self, in_channels, out_channels, K): 
        super(Block, self).__init__()
        self.in_channels = in_channels # defining input no of channels 
        self.out_channels = out_channels # defining output no of channels 
        self.K = K # defining the number of iterations of a * conv(x)

        # linear mlp layer
        self.fc = nn.Linear(in_channels, K)

        # spatial average pooling layer of input tensor using AdaptiveAvgPool2d
        self.spatial_pool = nn.AdaptiveAvgPool2d(1) 

        # choosing sigmoid as non-linear activation function
        self.activation = nn.Sigmoid()

        # defining the final summation output of 'a' and 'convolution layer' 
        self.convs = nn.ModuleList()
        for i in range(K):
            self.convs.append(nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1, stride=1, bias=False))

    def forward(self, x):
        # computing vector 'a' -> non-linear activation * spatial avg pool (x)
        a = self.spatial_pool(x).view(x.size(0), self.in_channels)
        a = self.fc(a)
        a = self.activation(a)

        # computing the final output -> sum of 'a' * 'conv layer' till K
        out = 0
        for i in range(self.K):
            out += a[:, i].view(x.size(0), 1, 1, 1) * self.convs[i](x) # clarification

        return out

# %%
'''
understanding architecture of block class with input of 3 channels!
'''
block_model = Block(3, 64, K=4)
block_model
# Out:
# Block(
#   (fc): Linear(in_features=3, out_features=4, bias=True)
#   (spatial_pool): AdaptiveAvgPool2d(output_size=1)
#   (activation): Sigmoid()
#   (convs): ModuleList(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (3): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
# )

# %%
'''
defining the final Backbone Model architecture

implementing the following model layers : 
-> 5 layers of Block class with variations in/out channe
-> sigmoid function as an activation layer
-> average pooling with kernal size = 2x2 and stride = 1 as a pooling layer

classifer layer :
-> adaptive average pooling used on the output from the last block layer
-> thereafter it is flattened and a simple mlp layer is used to translate the out channels to 10 label classes
'''

class BackboneModel(nn.Module):
    def __init__(self, num_classes=10):
        super(BackboneModel, self).__init__()
        
        self.num_classes = num_classes
        
        #defining the activation and pooling functions
        self.Sigmoid = nn.Sigmoid()
        self.Avg = nn.AvgPool2d(2, stride=1)
        
        # defining blocks used to create the model with it's corresponding batch normalisation
        self.block0 = Block(3, 64, K=3)
        self.bn0 = nn.BatchNorm2d(64)
        
        self.block1 = Block(64, 64, K=3)
        self.bn1 = nn.BatchNorm2d(64)
        
        self.block2 = Block(64, 128, K=3)
        self.bn2 = nn.BatchNorm2d(128)
        
        self.block3 = Block(128, 128, K=3)
        self.bn3 = nn.BatchNorm2d(128)
        
        self.block4 = Block(128, 256, K=3)
        self.bn4 = nn.BatchNorm2d(256)
        
        self.block5 = Block(256, 256, K=3)
        self.bn5 = nn.BatchNorm2d(256)
        
        # defining the final classifier layer -> according to the requirement of the coursework
        self.spatial_pool = nn.AdaptiveAvgPool2d(1)
        self.Fltn = nn.Flatten()
        self.classifier = nn.Linear(256, num_classes)

    def forward(self, x):
          
        # final backbone model -> shown below is the best model providing the best accuracy yet!
        
        x = self.block0(x)
        x = self.Sigmoid(x)
        x = self.bn0(x)
        
        x = self.block1(x)
        x = self.Sigmoid(x)
        x = self.Avg(x)
        x = self.bn1(x)
        
        x = self.block2(x)
        x = self.Sigmoid(x)
        x = self.Avg(x)
        x = self.bn2(x)
        
        x = self.block3(x)
        x = self.Sigmoid(x)
        x = self.Avg(x)
        x = self.bn3(x)
      
        x = self.block4(x)
        x = self.Sigmoid(x)
        x = self.Avg(x)
        x = self.bn4(x)
        
        x = self.block5(x)
        x = self.Sigmoid(x)
        x = self.Avg(x)
        x = self.bn5(x) 
        
        # final classification layer
        
        x = self.spatial_pool(x)
        x = self.Fltn(x)
        x = self.classifier(x)

        return x

# %%
'''
initialzing model to use device = gpu or cpu for training!
'''

backbone = BackboneModel().to(device)

# %%
'''
defining loss and optimizer functions and it's corresponding hyperparameters 

'''

num_epochs = 60                 # running for 80 epochs

loss_fn = nn.CrossEntropyLoss() # choosing cross entropy loss as loss function

optimizer = optim.Adam(         # choosing adam optimzer 
    backbone.parameters(),
    lr=0.001,
    betas=(0.9, 0.999),         # decay rates for moving averages of gradient and its square
    eps=1e-08,                  # term added to the denominator to improve numerical stability
    weight_decay=0.0001)        # L2 regularization parameter

# %%
start_time = time.time()

# list to store corresponding train accuracy, train loss, test accuray per epoch
train_losses = [] 
train_accs = []

test_accs = []

print('started training -->')


for epoch in range(num_epochs):
    
    '''
    training iteration
    '''
    run_loss_train = 0.0
    run_acc_train = 0.0
    for images, labels in trainloader:
        images = images.to(device)
        labels = labels.to(device)
        
        
        # forward pass
        outputs = backbone(images)
        loss = loss_fn(outputs, labels)

        # fackward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # update running loss and accuracy
        run_loss_train += loss.item()
        preds_train = outputs.argmax(dim=1)
        run_acc_train += torch.sum(preds_train == labels).item() / labels.size(0)



    # compute & save epoch loss and accuracy for each epoch
    epoch_loss = run_loss_train / len(trainloader)
    epoch_acc = run_acc_train / len(trainloader)
    train_losses.append(epoch_loss)
    train_accs.append(epoch_acc)
    
    
    '''
    validation iteration
    '''
    with torch.no_grad(): # no gradient calculation while computing test/validation accuracy
        running_acc_val = 0.0
        for images, labels in testloader:
            images = images.to(device)
            labels = labels.to(device)

            # forward pass
            outputs_val = backbone(images)

            # compute validation accuracy
            preds_val = outputs_val.argmax(dim=1)
            running_acc_val += torch.sum(preds_val == labels).item() / labels.size(0)

    # compute & save val accuracy for each epoch
    test_epoch_acc = running_acc_val / len(testloader)
    test_accs.append(test_epoch_acc)
    
    # print status per epoch
    print('Epoch [{}/{}], Train Loss: {:.4f}, Train Accuracy : {:.4f}, Test Accuracy : {:.4f}'.format(epoch+1, num_epochs, epoch_loss, epoch_acc, test_epoch_acc))
    
    
    
    #torch.cuda.empty_cache() # using to free up GPU space!
    

end_time = time.time()

print("training completed in : {:.2f} seconds".format(end_time - start_time))


# save model locally
# torch.save(backbone.state_dict(), 'model-3-003.pt')
# Out:
# started training -->
# Epoch [1/60], Train Loss: 1.7491, Train Accuracy : 0.3424, Test Accuracy : 0.4446
# Epoch [2/60], Train Loss: 1.3071, Train Accuracy : 0.5296, Test Accuracy : 0.5732
# Epoch [3/60], Train Loss: 1.1208, Train Accuracy : 0.5992, Test Accuracy : 0.6231
# Epoch [4/60], Train Loss: 1.0016, Train Accuracy : 0.6466, Test Accuracy : 0.6575
# Epoch [5/60], Train Loss: 0.9125, Train Accuracy : 0.6780, Test Accuracy : 0.6869
# Epoch [6/60], Train Loss: 0.8437, Train Accuracy : 0.7005, Test Accuracy : 0.7117
# Epoch [7/60], Train Loss: 0.7875, Train Accuracy : 0.7259, Test Accuracy : 0.7189
# Epoch [8/60], Train Loss: 0.7348, Train Accuracy : 0.7438, Test Accuracy : 0.7234
# Epoch [9/60], Train Loss: 0.6902, Train Accuracy : 0.7599, Test Accuracy : 0.7504
# Epoch [10/60], Train Loss: 0.6517, Train Accuracy : 0.7740, Test Accuracy : 0.7617
# Epoch [11/60], Train Loss: 0.6193, Train Accuracy : 0.7854, Test Accuracy : 0.7692
# Epoch [12/60], Train Loss: 0.5837, Train Accuracy : 0.7983, Test Accuracy : 0.7726
# Epoch [13/60], Train Loss: 0.5643, Train Accuracy : 0.8058, Test Accuracy : 0.7842
# Epoch [14/60], Train Loss: 0.5455, Train Accuracy : 0.8116, Test Accuracy : 0.7927
# Epoch [15/60], Train Loss: 0.5242, Train Accuracy : 0.8193, Test Accuracy : 0.7972
# Epoch [16/60], Train Loss: 0.5095, Train Accuracy : 0.8263, Test Accuracy : 0.7895
# Epoch [17/60], Train Loss: 0.4967, Train Accuracy : 0.8278, Test Accuracy : 0.8078
# Epoch [18/60], Train Loss: 0.4772, Train Accuracy : 0.8378, Test Accuracy : 0.8056
# Epoch [19/60], Train Loss: 0.4706, Train Accuracy : 0.8368, Test Accuracy : 0.8022
# Epoch [20/60], Train Loss: 0.4588, Train Accuracy : 0.8403, Test Accuracy : 0.8171
# Epoch [21/60], Train Loss: 0.4484, Train Accuracy : 0.8460, Test Accuracy : 0.8157
# Epoch [22/60], Train Loss: 0.4388, Train Accuracy : 0.8480, Test Accuracy : 0.8179
# Epoch [23/60], Train Loss: 0.4286, Train Accuracy : 0.8523, Test Accuracy : 0.8309
# Epoch [24/60], Train Loss: 0.4218, Train Accuracy : 0.8537, Test Accuracy : 0.8296
# Epoch [25/60], Train Loss: 0.4136, Train Accuracy : 0.8579, Test Accuracy : 0.8224
# Epoch [26/60], Train Loss: 0.4051, Train Accuracy : 0.8605, Test Accuracy : 0.8306
# Epoch [27/60], Train Loss: 0.4036, Train Accuracy : 0.8613, Test Accuracy : 0.8258
# Epoch [28/60], Train Loss: 0.3937, Train Accuracy : 0.8646, Test Accuracy : 0.8280
# Epoch [29/60], Train Loss: 0.3862, Train Accuracy : 0.8672, Test Accuracy : 0.8239
# Epoch [30/60], Train Loss: 0.3818, Train Accuracy : 0.8691, Test Accuracy : 0.8335
# Epoch [31/60], Train Loss: 0.3774, Train Accuracy : 0.8698, Test Accuracy : 0.8357
# Epoch [32/60], Train Loss: 0.3714, Train Accuracy : 0.8728, Test Accuracy : 0.8345
# Epoch [33/60], Train Loss: 0.3655, Train Accuracy : 0.8745, Test Accuracy : 0.8338
# Epoch [34/60], Train Loss: 0.3612, Train Accuracy : 0.8744, Test Accuracy : 0.8358
# Epoch [35/60], Train Loss: 0.3619, Train Accuracy : 0.8752, Test Accuracy : 0.8353
# Epoch [36/60], Train Loss: 0.3536, Train Accuracy : 0.8796, Test Accuracy : 0.8385
# Epoch [37/60], Train Loss: 0.3507, Train Accuracy : 0.8784, Test Accuracy : 0.8347
# Epoch [38/60], Train Loss: 0.3437, Train Accuracy : 0.8816, Test Accuracy : 0.8445
# Epoch [39/60], Train Loss: 0.3470, Train Accuracy : 0.8796, Test Accuracy : 0.8354
# Epoch [40/60], Train Loss: 0.3409, Train Accuracy : 0.8818, Test Accuracy : 0.8447
# Epoch [41/60], Train Loss: 0.3392, Train Accuracy : 0.8824, Test Accuracy : 0.8401
# Epoch [42/60], Train Loss: 0.3346, Train Accuracy : 0.8857, Test Accuracy : 0.8384
# Epoch [43/60], Train Loss: 0.3303, Train Accuracy : 0.8870, Test Accuracy : 0.8428
# Epoch [44/60], Train Loss: 0.3241, Train Accuracy : 0.8881, Test Accuracy : 0.8514
# Epoch [45/60], Train Loss: 0.3269, Train Accuracy : 0.8879, Test Accuracy : 0.8434
# Epoch [46/60], Train Loss: 0.3239, Train Accuracy : 0.8887, Test Accuracy : 0.8502
# Epoch [47/60], Train Loss: 0.3214, Train Accuracy : 0.8892, Test Accuracy : 0.8541
# Epoch [48/60], Train Loss: 0.3222, Train Accuracy : 0.8880, Test Accuracy : 0.8461
# Epoch [49/60], Train Loss: 0.3144, Train Accuracy : 0.8916, Test Accuracy : 0.8444
# Epoch [50/60], Train Loss: 0.3172, Train Accuracy : 0.8901, Test Accuracy : 0.8520
# Epoch [51/60], Train Loss: 0.3146, Train Accuracy : 0.8922, Test Accuracy : 0.8475
# Epoch [52/60], Train Loss: 0.3056, Train Accuracy : 0.8930, Test Accuracy : 0.8473
# Epoch [53/60], Train Loss: 0.3073, Train Accuracy : 0.8949, Test Accuracy : 0.8464
# Epoch [54/60], Train Loss: 0.3035, Train Accuracy : 0.8955, Test Accuracy : 0.8532
# Epoch [55/60], Train Loss: 0.3032, Train Accuracy : 0.8949, Test Accuracy : 0.8515
# Epoch [56/60], Train Loss: 0.2973, Train Accuracy : 0.8972, Test Accuracy : 0.8554
# Epoch [57/60], Train Loss: 0.2953, Train Accuracy : 0.8985, Test Accuracy : 0.8464
# Epoch [58/60], Train Loss: 0.2986, Train Accuracy : 0.8947, Test Accuracy : 0.8459
# Epoch [59/60], Train Loss: 0.2914, Train Accuracy : 0.8999, Test Accuracy : 0.8510
# Epoch [60/60], Train Loss: 0.2951, Train Accuracy : 0.8982, Test Accuracy : 0.8590
# training completed in : 2660.16 seconds

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 3))
fig.tight_layout(pad=2.5)

'''
plot train vs test/validation accuracy
'''

ax1.plot(train_accs, label='train acc')
ax1.plot(test_accs, label='test acc')
ax1.grid(axis='y')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.set_title('Train vs Test Accuracy')
ax1.legend()

'''
plot train loss
'''
ax2.plot(train_losses, label='train loss')
ax2.grid(axis='y')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.set_title('Train Loss')
ax2.legend()


plt.show()

# %%
'''
showing predicted response for 10 items from test/validation dataset
'''

def imshow2(img):
    transform = transforms.Compose([transforms.Resize((128, 128))])
    img = transform(img)
    img = img / 2 + 0.5  # unnormalize
    npimg = img.cpu().numpy()[0]
    fig, ax = plt.subplots(figsize=(2, 2))
    ax.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# model on evaluation mode
backbone.eval()


count = 0

with torch.no_grad(): # no gradient calculation while computing over test/validation data
    for images, labels in testloader:
        images = images.to(device)
        labels = labels.to(device)

        # forward pass
        outputs = backbone(images)

        # compute predicted labels
        predicted = outputs.argmax(dim=1)

        # visualise first 10 predictions from the test/validation dataset
        pred_label_class = classes[predicted.tolist()[0]]
        actual_label_class = classes[labels.tolist()[0]]
        status = 'Correct Prediction' if predicted.tolist()[0] == labels.tolist()[0] else 'Incorrect Prediction'
        print('Actual: {} | Predicted  : {}'.format(actual_label_class, pred_label_class))
        print(status)
        imshow2(images)
        print('-----------------------------------------')
        
        if count == 10:
            break
        
        count +=1
# Out:
# Actual: dog | Predicted  : dog
# Correct Prediction
# -----------------------------------------
# Actual: bird | Predicted  : bird
# Correct Prediction
# -----------------------------------------
# Actual: deer | Predicted  : deer
# Correct Prediction
# -----------------------------------------
# Actual: ship | Predicted  : ship
# Correct Prediction
# -----------------------------------------
# Actual: bird | Predicted  : frog
# Incorrect Prediction
# -----------------------------------------
# Actual: car | Predicted  : car
# Correct Prediction
# -----------------------------------------
# Actual: horse | Predicted  : horse
# Correct Prediction
# -----------------------------------------
# Actual: deer | Predicted  : deer
# Correct Prediction
# -----------------------------------------
# Actual: ship | Predicted  : ship
# Correct Prediction
# -----------------------------------------
# Actual: plane | Predicted  : plane
# Correct Prediction
# -----------------------------------------
# Actual: cat | Predicted  : car
# Incorrect Prediction
# -----------------------------------------

# %% [markdown]
# ## References for code snippets and inspiration
#
# - dataloader + baisc understanding of flow - https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html
# - training + validation epoch loops - https://www.kaggle.com/code/vikasbhadoria/cifar10-high-accuracy-model-build-on-pytorch
# - understanding best custom implementation on cifar10 dataset - https://github.com/iVishalr/cifar10-pytorch/blob/main/notebook/CIFAR10.ipynb
# - undestanding use of data augmentation to improve accuracy - https://medium.com/@nagam808surya/cifar-10-image-classification-using-pytorch-90332041ba1f
# - understanding use of LR and scheduler for optimizer - https://discuss.pytorch.org/t/how-to-choose-learning-rate-and-scheduler/174319
